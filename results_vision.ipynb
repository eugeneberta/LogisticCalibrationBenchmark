# %%
import pandas as pd
from utils import df_to_latex_table

# %%
results = pd.read_csv('results/ComputerVision/results.csv')
results_imagenet = pd.read_csv('results/ComputerVision/results_imagenet.csv')

# %%
results[['dataset', 'model', 'base_logloss', 'ts_logloss', 'torch_vs_logloss', 'svs_logloss', 'torch_ms_logloss', 'sms_logloss', 'dir_ms_logloss']].sort_values('dataset')
# Out:
#   dataset          model  base_logloss  ts_logloss  torch_vs_logloss  \
# 0     c10     densenet40      0.430059    0.224423          0.224403
# 2     c10         lenet5      0.823261    0.800275          0.747161
# 4     c10      resnet110      0.358274    0.209307          0.207846
# 6     c10   resnet110_SD      0.304939    0.176873          0.176881
# 8     c10  resnet_wide32      0.382089    0.191426          0.183316
# 1    c100     densenet40      2.018243    1.057022          1.060737
# 3    c100         lenet5      2.783648    2.649680          2.517895
# 5    c100      resnet110      1.693712    1.091679          1.095663
# 7    c100   resnet110_SD      1.352503    0.942208          0.931607
# 9    c100  resnet_wide32      1.802246    0.944613          0.951085
#
#    svs_logloss  torch_ms_logloss  sms_logloss  dir_ms_logloss
# 0     0.222394          0.227232     0.220804        0.224063
# 2     0.749968          0.745845     0.742861        0.746927
# ...

# %%
results[['dataset', 'model', 'base_brier', 'ts_brier', 'torch_vs_brier', 'svs_brier', 'torch_ms_brier', 'sms_brier', 'dir_ms_brier']].sort_values('dataset')
# Out:
#   dataset          model  base_brier  ts_brier  torch_vs_brier  svs_brier  \
# 0     c10     densenet40    0.127379  0.109972        0.110075   0.109671
# 2     c10         lenet5    0.378799  0.374759        0.352261   0.353590
# 4     c10      resnet110    0.110189  0.097850        0.098001   0.097492
# 6     c10   resnet110_SD    0.098139  0.087370        0.086862   0.086671
# 8     c10  resnet_wide32    0.104662  0.092372        0.088866   0.089029
# 1    c100     densenet40    0.490662  0.400889        0.401613   0.399836
# 3    c100         lenet5    0.812801  0.792465        0.766866   0.782112
# 5    c100      resnet110    0.453330  0.391855        0.391107   0.391449
# 7    c100   resnet110_SD    0.418404  0.366863        0.359370   0.364046
# 9    c100  resnet_wide32    0.432035  0.354769        0.351788   0.353737
#
#    torch_ms_brier  sms_brier  dir_ms_brier
# 0        0.112201   0.109812      0.111180
# 2        0.351807   0.350303      0.351926
# ...

# %%
print(df_to_latex_table(results, 'logloss'))
# Out:
# \begin{tabular}{ll|cccccc}
# \toprule
# dataset & model & TS & SVS & TorchCal VS & SMS & TorchCal MS & Dirichlet MS \\
# \midrule
# CIFAR-10 & densenet40 & -0.206 & -0.208 & -0.206 & \textbf{-0.209} & -0.203 & -0.206 \\
# CIFAR-10 & lenet5 & -0.023 & -0.073 & -0.076 & \textbf{-0.080} & -0.077 & -0.076 \\
# CIFAR-10 & resnet110 & -0.149 & -0.151 & -0.150 & \textbf{-0.155} & -0.146 & -0.149 \\
# CIFAR-10 & resnet110-SD & -0.128 & -0.130 & -0.128 & \textbf{-0.130} & -0.116 & -0.121 \\
# CIFAR-10 & resnet-wide32 & -0.191 & -0.199 & -0.199 & \textbf{-0.201} & -0.189 & -0.192 \\
# CIFAR-100 & densenet40 & -0.961 & -0.967 & -0.958 & \textbf{-0.970} & 28.982 & 1.075 \\
# CIFAR-100 & lenet5 & -0.134 & -0.219 & -0.266 & \textbf{-0.273} & 8.204 & 0.166 \\
# CIFAR-100 & resnet110 & -0.602 & \textbf{-0.608} & -0.598 & -0.608 & 35.361 & 0.400 \\
# CIFAR-100 & resnet110-SD & -0.410 & -0.423 & -0.421 & \textbf{-0.437} & 37.586 & 1.201 \\
# ...

# %%
print(df_to_latex_table(results, 'brier'))
# Out:
# \begin{tabular}{ll|cccccc}
# \toprule
# dataset & model & TS & SVS & TorchCal VS & SMS & TorchCal MS & Dirichlet MS \\
# \midrule
# CIFAR-10 & densenet40 & -0.017 & \textbf{-0.018} & -0.017 & -0.018 & -0.015 & -0.016 \\
# CIFAR-10 & lenet5 & -0.004 & -0.025 & -0.027 & \textbf{-0.028} & -0.027 & -0.027 \\
# CIFAR-10 & resnet110 & -0.012 & -0.013 & -0.012 & \textbf{-0.013} & -0.009 & -0.010 \\
# CIFAR-10 & resnet110-SD & -0.011 & -0.011 & -0.011 & \textbf{-0.012} & -0.008 & -0.009 \\
# CIFAR-10 & resnet-wide32 & -0.012 & -0.016 & \textbf{-0.016} & -0.016 & -0.011 & -0.012 \\
# CIFAR-100 & densenet40 & -0.090 & -0.091 & -0.089 & \textbf{-0.092} & 0.492 & 0.170 \\
# CIFAR-100 & lenet5 & -0.020 & -0.031 & -0.046 & \textbf{-0.047} & 0.337 & 0.025 \\
# CIFAR-100 & resnet110 & -0.061 & -0.062 & \textbf{-0.062} & -0.062 & 0.406 & 0.100 \\
# CIFAR-100 & resnet110-SD & -0.052 & -0.054 & -0.059 & \textbf{-0.060} & 0.522 & 0.183 \\
# ...

# %%
print(df_to_latex_table(results_imagenet, 'logloss'))
# Out:
# \begin{tabular}{ll|ccc}
# \toprule
# dataset & model & TS & SVS & TorchCal VS \\
# \midrule
# imgnet & densenet161 & -0.035 & \textbf{-0.037} & 0.007 \\
# imgnet & resnet152 & -0.047 & \textbf{-0.049} & -0.015 \\
# \bottomrule
# \end{tabular}

# %%
print(df_to_latex_table(results_imagenet, 'brier'))
# Out:
# \begin{tabular}{ll|ccc}
# \toprule
# dataset & model & TS & SVS & TorchCal VS \\
# \midrule
# imgnet & densenet161 & -0.004 & \textbf{-0.004} & -0.004 \\
# imgnet & resnet152 & -0.006 & \textbf{-0.006} & -0.004 \\
# \bottomrule
# \end{tabular}

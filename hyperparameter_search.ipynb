# %%
import json
import optuna
import numpy as np
import pandas as pd

from tabrepo import load_repository
from probmetrics.calibrators import get_calibrator

import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# We solve the following convex optimization problem:
# $$
# \frac{1}{n} \sum_{i=1}^n \ell(S((aI + \text{diag}(\mathbf{v}) + M \odot (11^\top-I)) \mathbf{z}_i + \mathbf{b}), y_i) + \lambda_\mathbf{b} \frac{k^\rho}{n^\tau}\|\mathbf{b}\|_\delta + \lambda_\mathbf{v} \frac{k^\rho}{n^\tau}\|\mathbf{v}\|_\delta + \lambda_M \frac{((k-1)k)^\rho}{n^\tau}\|\mathbf{M}\|_\delta \quad .
# $$
#
# We experiment with the following parameters:
# - $\delta$ the order of the norm is $1$ (lasso), $2$ (group-lasso) or $2$-squared (ridge).
# - $\rho$ the power of the number of parameters in $\{-1, -0.5, 0, 0.5, 1 \}$.
# - $\tau$ the power of the number of samples is $\{0.5, 1, 1.5, 2 \}$.
# - $\lambda_\mathbf{b}$, $\lambda_\mathbf{v}$, $\lambda_M$ the intercept, diagonal and off-diagonal regularization coefficients in the range $[0.01, 100]$.

# %%
repo = load_repository("D244_F3_C1530_200")
configs = pd.read_csv('results/multiclass/configs.csv', index_col=0)
# Out:
# start: Loading ZS Context
# Loading BenchmarkContext:
# 	name: D244_F3_C1530_200
# 	description: Large-scale Benchmark on 244 datasets and 3 folds (120 GB, 200 smallest datasets)
# 	date: 2023_11_14
# 	folds: [0, 1, 2]
# All required files are present...
# Loading input files...
# 	configs :           /Users/eberta/.cache/tabrepo/data/results/2023_11_14/configs.parquet
# 	metadata:           /Users/eberta/.cache/tabrepo/data/results/2023_11_14/task_metadata.csv
# Loading baselines: /Users/eberta/.cache/tabrepo/data/results/2023_11_14/baselines.parquet
# Loading config hyperparameter definitions... Note: Hyperparameter definitions are only accurate for the latest version.
# Loading ZS inputs:
# 	pred_proba:  /Users/eberta/.cache/tabrepo/data/results/2023_11_14/model_predictions/
#
# Aligning GroundTruth with TabularPredictions... (Dataset count 200 -> 200)
# Time for Loading ZS Context: 8.9770 secs

# %%
def brier_score_multiclass(probs, labels):
    n_samples, _ = probs.shape
    one_hot = np.zeros_like(probs)
    one_hot[np.arange(n_samples), labels] = 1
    squared_error = np.sum(np.square(probs - one_hot), axis=-1)
    return np.mean(squared_error)

# %%
def benchmark_multiclass_calibrator(cal, configs):

    improvements = []

    for _, row in configs.iterrows():
        dataset, fold, config = row['dataset'], row['fold'], row['tuned_config']
        
        p_cal = repo.predict_val(dataset=dataset, fold=fold, config=config)
        y_cal = repo.labels_val(dataset=dataset, fold=fold)
        p_test = repo.predict_test(dataset=dataset, fold=fold, config=config)
        y_test = repo.labels_test(dataset=dataset, fold=fold)

        n_cal, _ = p_cal.shape

        # subsampling large datasets:
        if n_cal > 10000:
            np.random.seed(123)
            idx = np.arange(0, n_cal)
            rand_idx = np.random.choice(idx, 10000, replace=False)
            p_cal = p_cal[rand_idx]
            y_cal = y_cal[rand_idx]

        base_score = brier_score_multiclass(p_test, y_test)

        cal.fit(p_cal, y_cal)
        cal_score = brier_score_multiclass(cal.predict_proba(p_test), y_test)

        improvements.append(cal_score - base_score)

    return np.array(improvements)

# %%
# Splitting datasets in two for gridsearch and benchmark using ts effect:
ts = get_calibrator('ts-mix')
ts_improvement = benchmark_multiclass_calibrator(ts, configs)
configs['ts_improvement'] = ts_improvement

df = configs.groupby(['dataset']).agg({'ts_improvement':'mean'}).reset_index()

datasets = df.dataset.tolist()
ts_effect = df.ts_improvement.tolist()

arg = np.argsort(ts_effect)

search_datasets = [datasets[i] for i in arg[::2]]
bench_datasets = list(set(datasets) - set(search_datasets))

search_configs = configs[configs.dataset.isin(search_datasets)]
bench_configs = configs[configs.dataset.isin(bench_datasets)]

# %%
with open("results/multiclass/search_datasets.json", 'w') as f:
    json.dump(search_datasets, f, indent=2)
with open("results/multiclass/bench_datasets.json", 'w') as f:
    json.dump(bench_datasets, f, indent=2)

# %% [markdown]
# Evaluating ts on search datasets for reference:

# %%
ts = get_calibrator('ts-mix')
ts_improvement = benchmark_multiclass_calibrator(ts, search_configs)
print(f'ts mean absolute improvement {ts_improvement.mean():.5f}')
# Out:
# ts mean absolute improvement -0.00274

# %% [markdown]
# Evaluating ts on bench datasets for reference:

# %%
ts = get_calibrator('ts-mix')
ts_improvement = benchmark_multiclass_calibrator(ts, bench_configs)
print(f'ts mean absolute improvement {ts_improvement.mean():.5f}')
# Out:
# ts mean absolute improvement -0.00201

# %% [markdown]
# # SVS parameter search

# %%
def objective(trial):
    rho = trial.suggest_categorical('rho', [-1.0, -0.5, 0.0, 0.5, 1.0])
    tau = trial.suggest_categorical('tau', [0.5, 1.0, 1.5, 2.0])
    lambda_intercept = trial.suggest_float('lambda_intercept', 1e-2, 1e2, log=True)
    lambda_diagonal = trial.suggest_float('lambda_diagonal', 1e-2, 1e2, log=True)

    svs = get_calibrator(
        'svs',
        svs_rho = rho,
        svs_tau = tau,
        svs_lambda_intercet = lambda_intercept,
        svs_lambda_diagonal = lambda_diagonal
    )
    improvement = benchmark_multiclass_calibrator(svs, search_configs)

    return improvement.mean()

study = optuna.create_study()
study.optimize(objective, n_trials=100)
# Out:
# [I 2026-01-08 16:50:15,574] A new study created in memory with name: no-name-b711e93b-6c47-4df9-b1a3-f6138adc742b
# [I 2026-01-08 16:50:33,889] Trial 0 finished with value: -0.0044060442596673965 and parameters: {'rho': 0.5, 'tau': 2.0, 'lambda_intercept': 0.21714111308363937, 'lambda_diagonal': 0.2921769907045169}. Best is trial 0 with value: -0.0044060442596673965.
# [I 2026-01-08 16:50:52,079] Trial 1 finished with value: -0.004342087544500828 and parameters: {'rho': 0.0, 'tau': 2.0, 'lambda_intercept': 30.286764096294817, 'lambda_diagonal': 0.02008738406263097}. Best is trial 0 with value: -0.0044060442596673965.
# [I 2026-01-08 16:51:10,667] Trial 2 finished with value: -0.004306043032556772 and parameters: {'rho': -0.5, 'tau': 2.0, 'lambda_intercept': 0.2656215854829775, 'lambda_diagonal': 2.7365211644888356}. Best is trial 0 with value: -0.0044060442596673965.
# [I 2026-01-08 16:51:27,555] Trial 3 finished with value: -0.004192142281681299 and parameters: {'rho': -1.0, 'tau': 1.0, 'lambda_intercept': 0.05092947875141943, 'lambda_diagonal': 31.469366417526622}. Best is trial 0 with value: -0.0044060442596673965.
# [I 2026-01-08 16:51:37,932] Trial 4 finished with value: -0.0032431944273412228 and parameters: {'rho': 1.0, 'tau': 0.5, 'lambda_intercept': 9.072561063127413, 'lambda_diagonal': 0.1250508706687944}. Best is trial 0 with value: -0.0044060442596673965.
# [I 2026-01-08 16:51:48,351] Trial 5 finished with value: -0.003267546882852912 and parameters: {'rho': 1.0, 'tau': 0.5, 'lambda_intercept': 99.56696305924308, 'lambda_diagonal': 0.09509082235603969}. Best is trial 0 with value: -0.0044060442596673965.
# [I 2026-01-08 16:52:01,151] Trial 6 finished with value: -0.0037467810325324535 and parameters: {'rho': 1.0, 'tau': 1.0, 'lambda_intercept': 19.561244200700298, 'lambda_diagonal': 2.787537409561648}. Best is trial 0 with value: -0.0044060442596673965.
# [I 2026-01-08 16:52:20,465] Trial 7 finished with value: -0.0045343730598688126 and parameters: {'rho': -1.0, 'tau': 1.0, 'lambda_intercept': 4.996893820068412, 'lambda_diagonal': 0.01315621304571616}. Best is trial 7 with value: -0.0045343730598688126.
# [I 2026-01-08 16:52:30,294] Trial 8 finished with value: -0.003257162170484662 and parameters: {'rho': 1.0, 'tau': 0.5, 'lambda_intercept': 3.269628050580386, 'lambda_diagonal': 0.10716498301690956}. Best is trial 7 with value: -0.0045343730598688126.
# [I 2026-01-08 16:52:49,065] Trial 9 finished with value: -0.004283886402845383 and parameters: {'rho': -1.0, 'tau': 2.0, 'lambda_intercept': 0.597480185184761, 'lambda_diagonal': 0.4340175068225368}. Best is trial 7 with value: -0.0045343730598688126.
# [I 2026-01-08 16:53:08,825] Trial 10 finished with value: -0.004349214490503073 and parameters: {'rho': -1.0, 'tau': 1.5, 'lambda_intercept': 0.01610994078277312, 'lambda_diagonal': 0.010791015417845084}. Best is trial 7 with value: -0.0045343730598688126.
# [I 2026-01-08 16:53:21,952] Trial 11 finished with value: -0.0036335689947009087 and parameters: {'rho': 0.5, 'tau': 1.0, 'lambda_intercept': 0.17488538217063793, 'lambda_diagonal': 32.76954971566394}. Best is trial 7 with value: -0.0045343730598688126.
# [I 2026-01-08 16:53:38,442] Trial 12 finished with value: -0.004574294667690992 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 1.4527222605571948, 'lambda_diagonal': 1.0409522547942598}. Best is trial 12 with value: -0.004574294667690992.
# [I 2026-01-08 16:53:55,367] Trial 13 finished with value: -0.004554500803351402 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 2.250153670561259, 'lambda_diagonal': 2.305099367766239}. Best is trial 12 with value: -0.004574294667690992.
# [I 2026-01-08 16:54:13,836] Trial 14 finished with value: -0.004507747478783131 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 1.6174927473342513, 'lambda_diagonal': 5.391134178078929}. Best is trial 12 with value: -0.004574294667690992.
# [I 2026-01-08 16:54:30,208] Trial 15 finished with value: -0.004468104802072048 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 1.334614122687155, 'lambda_diagonal': 8.552314670010855}. Best is trial 12 with value: -0.004574294667690992.
# [I 2026-01-08 16:54:47,062] Trial 16 finished with value: -0.0045773908495903015 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 0.7087684058422897, 'lambda_diagonal': 0.6582887936670458}. Best is trial 16 with value: -0.0045773908495903015.
# [I 2026-01-08 16:55:05,082] Trial 17 finished with value: -0.00451646326109767 and parameters: {'rho': 0.0, 'tau': 1.5, 'lambda_intercept': 0.5318682316133693, 'lambda_diagonal': 0.7650162623132848}. Best is trial 16 with value: -0.0045773908495903015.
# [I 2026-01-08 16:55:22,564] Trial 18 finished with value: -0.004318396095186472 and parameters: {'rho': -0.5, 'tau': 1.5, 'lambda_intercept': 0.06768734270898735, 'lambda_diagonal': 94.98134320777594}. Best is trial 16 with value: -0.0045773908495903015.
# [I 2026-01-08 16:55:39,356] Trial 19 finished with value: -0.004567774944007397 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 0.6548637978857929, 'lambda_diagonal': 1.3890199486924628}. Best is trial 16 with value: -0.0045773908495903015.
# [I 2026-01-08 16:55:57,715] Trial 20 finished with value: -0.004578365944325924 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 0.0764952801104561, 'lambda_diagonal': 0.2605517855092465}. Best is trial 20 with value: -0.004578365944325924.
# [I 2026-01-08 16:56:15,142] Trial 21 finished with value: -0.0045774406753480434 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 0.011504617905744361, 'lambda_diagonal': 0.2803597533383916}. Best is trial 20 with value: -0.004578365944325924.
# [I 2026-01-08 16:56:32,709] Trial 22 finished with value: -0.004567740019410849 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 0.012387260267428164, 'lambda_diagonal': 0.04575785755029551}. Best is trial 20 with value: -0.004578365944325924.
# [I 2026-01-08 16:56:51,182] Trial 23 finished with value: -0.0045768809504806995 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 0.048794806968247714, 'lambda_diagonal': 0.24199236150254855}. Best is trial 20 with value: -0.004578365944325924.
# [I 2026-01-08 16:57:09,071] Trial 24 finished with value: -0.004579488188028336 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 0.025555617010130337, 'lambda_diagonal': 0.5094572981468495}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 16:57:27,991] Trial 25 finished with value: -0.0045004975982010365 and parameters: {'rho': 0.0, 'tau': 1.5, 'lambda_intercept': 0.023446319578402864, 'lambda_diagonal': 0.04084016936385327}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 16:57:45,953] Trial 26 finished with value: -0.004430876579135656 and parameters: {'rho': -0.5, 'tau': 1.5, 'lambda_intercept': 0.029560634091813916, 'lambda_diagonal': 0.35648427260567045}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 16:58:04,622] Trial 27 finished with value: -0.0045766280964016914 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 0.12008606865061633, 'lambda_diagonal': 0.1718366857919914}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 16:58:16,416] Trial 28 finished with value: -0.0034844567999243736 and parameters: {'rho': 0.5, 'tau': 0.5, 'lambda_intercept': 0.012077950581175868, 'lambda_diagonal': 0.046465497521007225}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 16:58:35,048] Trial 29 finished with value: -0.00440537603572011 and parameters: {'rho': 0.5, 'tau': 2.0, 'lambda_intercept': 0.029855613846320166, 'lambda_diagonal': 0.4209480839866943}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 16:58:51,749] Trial 30 finished with value: -0.004577240906655788 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 0.09449641929992335, 'lambda_diagonal': 0.22715706486144138}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 16:59:08,017] Trial 31 finished with value: -0.004578737076371908 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 0.35712336038675313, 'lambda_diagonal': 0.7325199554790478}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 16:59:24,170] Trial 32 finished with value: -0.00456833653151989 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 0.29048536484766996, 'lambda_diagonal': 1.3332232272345834}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 16:59:41,028] Trial 33 finished with value: -0.004517077002674341 and parameters: {'rho': 0.0, 'tau': 1.5, 'lambda_intercept': 0.18295060699281662, 'lambda_diagonal': 0.5864762813014018}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 16:59:58,537] Trial 34 finished with value: -0.004403979983180761 and parameters: {'rho': 0.5, 'tau': 2.0, 'lambda_intercept': 0.04200138425308223, 'lambda_diagonal': 0.3132836485970806}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 17:00:17,360] Trial 35 finished with value: -0.004427565261721611 and parameters: {'rho': -0.5, 'tau': 1.5, 'lambda_intercept': 0.021527317028985405, 'lambda_diagonal': 0.15206361790794534}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 17:00:35,094] Trial 36 finished with value: -0.004571205470710993 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 0.0860132291857377, 'lambda_diagonal': 0.07593073486238304}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 17:00:47,544] Trial 37 finished with value: -0.0040797023102641106 and parameters: {'rho': 0.5, 'tau': 1.0, 'lambda_intercept': 0.010193958953114325, 'lambda_diagonal': 1.6070970562549058}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 17:00:55,848] Trial 38 finished with value: -0.0029915999621152878 and parameters: {'rho': 1.0, 'tau': 0.5, 'lambda_intercept': 0.2672514871658693, 'lambda_diagonal': 3.8167568914671315}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 17:01:13,205] Trial 39 finished with value: -0.00439510028809309 and parameters: {'rho': 0.5, 'tau': 2.0, 'lambda_intercept': 0.36707963118847914, 'lambda_diagonal': 0.06317616875665487}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 17:01:28,036] Trial 40 finished with value: -0.0045018382370471954 and parameters: {'rho': 0.0, 'tau': 1.0, 'lambda_intercept': 0.12861816047508712, 'lambda_diagonal': 0.0226316051586207}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 17:01:43,680] Trial 41 finished with value: -0.00457928329706192 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 0.9106457719390605, 'lambda_diagonal': 0.6306816571502034}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 17:01:59,559] Trial 42 finished with value: -0.004579446744173765 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 0.05317335000693855, 'lambda_diagonal': 0.5307731326106888}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 17:02:19,043] Trial 43 finished with value: -0.004576405975967646 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 0.059646891596167206, 'lambda_diagonal': 0.838231410806468}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 17:02:36,627] Trial 44 finished with value: -0.004363550804555416 and parameters: {'rho': -1.0, 'tau': 1.5, 'lambda_intercept': 0.3681148472586513, 'lambda_diagonal': 0.4677940558922332}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 17:02:44,314] Trial 45 finished with value: -0.003018386196345091 and parameters: {'rho': 1.0, 'tau': 0.5, 'lambda_intercept': 7.494515647102283, 'lambda_diagonal': 2.2882954836988016}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 17:03:00,758] Trial 46 finished with value: -0.004576094914227724 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 88.2395627373432, 'lambda_diagonal': 0.1660656969783428}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 17:03:17,946] Trial 47 finished with value: -0.004572919104248285 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 0.9586400734862981, 'lambda_diagonal': 1.0293661307484763}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 17:03:34,236] Trial 48 finished with value: -0.0043119583278894424 and parameters: {'rho': -1.0, 'tau': 1.0, 'lambda_intercept': 0.04012481756179647, 'lambda_diagonal': 11.769127889376213}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 17:03:50,992] Trial 49 finished with value: -0.0045788902789354324 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 3.85490690668039, 'lambda_diagonal': 0.5971552998587518}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 17:04:09,917] Trial 50 finished with value: -0.0042978813871741295 and parameters: {'rho': -0.5, 'tau': 2.0, 'lambda_intercept': 3.1596235329802447, 'lambda_diagonal': 0.5816100762742701}. Best is trial 24 with value: -0.004579488188028336.
# [I 2026-01-08 17:04:27,093] Trial 51 finished with value: -0.004580061417073011 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 17.743591095676003, 'lambda_diagonal': 0.4516002857720676}. Best is trial 51 with value: -0.004580061417073011.
# [I 2026-01-08 17:04:45,219] Trial 52 finished with value: -0.004574304446578026 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 6.434374227412555, 'lambda_diagonal': 0.9786140789521565}. Best is trial 51 with value: -0.004580061417073011.
# [I 2026-01-08 17:05:02,044] Trial 53 finished with value: -0.00456562964245677 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 14.29875957261292, 'lambda_diagonal': 1.5992617423770115}. Best is trial 51 with value: -0.004580061417073011.
# [I 2026-01-08 17:05:21,826] Trial 54 finished with value: -0.004579220898449421 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 20.358276352461946, 'lambda_diagonal': 0.5310831578531557}. Best is trial 51 with value: -0.004580061417073011.
# [I 2026-01-08 17:05:38,258] Trial 55 finished with value: -0.004580157343298197 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 27.75452837245174, 'lambda_diagonal': 0.45082383992872604}. Best is trial 55 with value: -0.004580157343298197.
# [I 2026-01-08 17:05:54,239] Trial 56 finished with value: -0.004550653044134378 and parameters: {'rho': 1.0, 'tau': 1.5, 'lambda_intercept': 40.3654203021827, 'lambda_diagonal': 0.11523763042868011}. Best is trial 55 with value: -0.004580157343298197.
# [I 2026-01-08 17:06:10,534] Trial 57 finished with value: -0.004579818807542324 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 30.366877536034547, 'lambda_diagonal': 0.4247254676234519}. Best is trial 55 with value: -0.004580157343298197.
# [I 2026-01-08 17:06:22,660] Trial 58 finished with value: -0.004162854049354792 and parameters: {'rho': -1.0, 'tau': 0.5, 'lambda_intercept': 55.117651328736066, 'lambda_diagonal': 0.3575750317773023}. Best is trial 55 with value: -0.004580157343298197.
# [I 2026-01-08 17:06:39,247] Trial 59 finished with value: -0.004576715175062418 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 15.42954751238733, 'lambda_diagonal': 0.22745423648747157}. Best is trial 55 with value: -0.004580157343298197.
# [I 2026-01-08 17:06:55,217] Trial 60 finished with value: -0.004557997453957796 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 24.770548242101597, 'lambda_diagonal': 2.094374814854546}. Best is trial 55 with value: -0.004580157343298197.
# [I 2026-01-08 17:07:11,208] Trial 61 finished with value: -0.00457951333373785 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 10.666200269834512, 'lambda_diagonal': 0.42312778361565606}. Best is trial 55 with value: -0.004580157343298197.
# [I 2026-01-08 17:07:27,393] Trial 62 finished with value: -0.004578958731144667 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 11.65731735845893, 'lambda_diagonal': 0.3654309777873026}. Best is trial 55 with value: -0.004580157343298197.
# [I 2026-01-08 17:07:43,327] Trial 63 finished with value: -0.004571177065372467 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 34.366522810772025, 'lambda_diagonal': 1.2398553977233164}. Best is trial 55 with value: -0.004580157343298197.
# [I 2026-01-08 17:07:59,909] Trial 64 finished with value: -0.004576594103127718 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 50.967109066774384, 'lambda_diagonal': 0.2077238495035789}. Best is trial 55 with value: -0.004580157343298197.
# [I 2026-01-08 17:08:16,225] Trial 65 finished with value: -0.004576310981065035 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 11.07556180002771, 'lambda_diagonal': 0.8092457995802457}. Best is trial 55 with value: -0.004580157343298197.
# [I 2026-01-08 17:08:33,105] Trial 66 finished with value: -0.004514290485531092 and parameters: {'rho': 0.0, 'tau': 1.5, 'lambda_intercept': 24.094550181698267, 'lambda_diagonal': 0.4285313050597018}. Best is trial 55 with value: -0.004580157343298197.
# [I 2026-01-08 17:08:49,377] Trial 67 finished with value: -0.00457802414894104 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 74.28942370772667, 'lambda_diagonal': 0.31334180140549606}. Best is trial 55 with value: -0.004580157343298197.
# [I 2026-01-08 17:09:04,297] Trial 68 finished with value: -0.004403851926326752 and parameters: {'rho': -0.5, 'tau': 1.0, 'lambda_intercept': 5.589617819295603, 'lambda_diagonal': 3.213920342183016}. Best is trial 55 with value: -0.004580157343298197.
# [I 2026-01-08 17:09:21,291] Trial 69 finished with value: -0.004574693273752928 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 28.033477995508267, 'lambda_diagonal': 0.13012914093274675}. Best is trial 55 with value: -0.004580157343298197.
# [I 2026-01-08 17:09:37,449] Trial 70 finished with value: -0.004577184095978737 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 2.0525178237374906, 'lambda_diagonal': 0.7570766627333787}. Best is trial 55 with value: -0.004580157343298197.
# [I 2026-01-08 17:09:53,637] Trial 71 finished with value: -0.004579487256705761 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 19.636848101432015, 'lambda_diagonal': 0.4752864437962774}. Best is trial 55 with value: -0.004580157343298197.
# [I 2026-01-08 17:10:10,097] Trial 72 finished with value: -0.004580901004374027 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 18.257300443238925, 'lambda_diagonal': 0.498580415150605}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:10:26,603] Trial 73 finished with value: -0.004579353611916304 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 16.05748250693682, 'lambda_diagonal': 0.4593503587258425}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:10:42,635] Trial 74 finished with value: -0.004577444866299629 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 9.312718379404888, 'lambda_diagonal': 0.2238044146468169}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:10:58,677] Trial 75 finished with value: -0.004578978288918734 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 36.4663115141573, 'lambda_diagonal': 0.328113138266787}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:11:15,210] Trial 76 finished with value: -0.004576962441205978 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 20.080262691360275, 'lambda_diagonal': 0.17956088966941777}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:11:31,943] Trial 77 finished with value: -0.004485248122364283 and parameters: {'rho': 1.0, 'tau': 2.0, 'lambda_intercept': 54.02081356118994, 'lambda_diagonal': 0.8947999124827389}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:11:40,139] Trial 78 finished with value: -0.0032211518846452236 and parameters: {'rho': 0.5, 'tau': 0.5, 'lambda_intercept': 42.62313856403655, 'lambda_diagonal': 1.2441240674596192}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:11:56,978] Trial 79 finished with value: -0.00457186670973897 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 8.20629145795825, 'lambda_diagonal': 0.08909572105181018}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:12:14,072] Trial 80 finished with value: -0.0045121414586901665 and parameters: {'rho': 0.0, 'tau': 1.5, 'lambda_intercept': 12.00951782337971, 'lambda_diagonal': 0.2778085674462666}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:12:30,411] Trial 81 finished with value: -0.0045807077549397945 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 15.709572617426293, 'lambda_diagonal': 0.4899957985043675}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:12:46,651] Trial 82 finished with value: -0.004578862804919481 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 28.626971862705666, 'lambda_diagonal': 0.5079058695451925}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:13:03,225] Trial 83 finished with value: -0.004579429980367422 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 17.9937394938387, 'lambda_diagonal': 0.40000705762119565}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:13:19,548] Trial 84 finished with value: -0.004578100983053446 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 13.38936827392411, 'lambda_diagonal': 0.7020133893319954}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:13:37,256] Trial 85 finished with value: -0.004362242761999369 and parameters: {'rho': -1.0, 'tau': 1.5, 'lambda_intercept': 65.93298261746452, 'lambda_diagonal': 0.29080928350853424}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:13:54,030] Trial 86 finished with value: -0.004579558502882719 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 21.11016216048946, 'lambda_diagonal': 0.5438338219314145}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:14:06,964] Trial 87 finished with value: -0.004132380709052086 and parameters: {'rho': 0.5, 'tau': 1.0, 'lambda_intercept': 22.382966616468597, 'lambda_diagonal': 1.0584112180808565}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:14:24,264] Trial 88 finished with value: -0.004441683646291494 and parameters: {'rho': -0.5, 'tau': 1.5, 'lambda_intercept': 10.382986147048115, 'lambda_diagonal': 1.7623935504273458}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:14:41,619] Trial 89 finished with value: -0.004412456415593624 and parameters: {'rho': 0.5, 'tau': 2.0, 'lambda_intercept': 4.829869107721829, 'lambda_diagonal': 0.666894141812226}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:14:58,376] Trial 90 finished with value: -0.0045761726796627045 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 31.681688660427984, 'lambda_diagonal': 0.1885380992546133}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:15:15,298] Trial 91 finished with value: -0.004578830674290657 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 17.04803480312897, 'lambda_diagonal': 0.5011606874939327}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:15:31,632] Trial 92 finished with value: -0.004579615779221058 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 0.023310357761328473, 'lambda_diagonal': 0.43663288492655866}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:15:47,989] Trial 93 finished with value: -0.004580031149089336 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 0.016057070878091932, 'lambda_diagonal': 0.3971244190354575}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:16:04,647] Trial 94 finished with value: -0.004579958505928516 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 0.016779420427426674, 'lambda_diagonal': 0.3501624459860251}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:16:21,696] Trial 95 finished with value: -0.004575509112328291 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 0.01944436543577432, 'lambda_diagonal': 0.14471939167567086}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:16:38,299] Trial 96 finished with value: -0.00457774056121707 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 0.014669003445400794, 'lambda_diagonal': 0.26349120194980746}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:16:54,643] Trial 97 finished with value: -0.004579054191708565 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 0.035045921824532915, 'lambda_diagonal': 0.3432463332282994}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:17:02,886] Trial 98 finished with value: -0.0031423268374055624 and parameters: {'rho': 1.0, 'tau': 0.5, 'lambda_intercept': 0.02061089413185533, 'lambda_diagonal': 0.40205901120429316}. Best is trial 72 with value: -0.004580901004374027.
# [I 2026-01-08 17:17:19,714] Trial 99 finished with value: -0.004577296786010265 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 0.013527395372969145, 'lambda_diagonal': 0.25385576547467686}. Best is trial 72 with value: -0.004580901004374027.

# %%
study.best_params
# Out:
# {'rho': 0.5,
#  'tau': 1.5,
#  'lambda_intercept': 18.257300443238925,
#  'lambda_diagonal': 0.498580415150605}

# %%
svs_default = get_calibrator('svs')

svs_tuned = get_calibrator(
    'svs',
    svs_rho = study.best_params['rho'],
    svs_tau = study.best_params['tau'],
    svs_lambda_intercet = study.best_params['lambda_intercept'],
    svs_lambda_diagonal = study.best_params['lambda_diagonal']
)

# %%
print('On search datasets:')
improvement = benchmark_multiclass_calibrator(svs_default, search_configs)
print(f'svs default mean improvement: {improvement.mean():.5f}')
improvement = benchmark_multiclass_calibrator(svs_tuned, search_configs)
print(f'svs tuned mean improvement:   {improvement.mean():.5f}\n')

print('On bench datasets:')
improvement = benchmark_multiclass_calibrator(svs_default, bench_configs)
print(f'svs default mean improvement: {improvement.mean():.5f}')
improvement = benchmark_multiclass_calibrator(svs_tuned, bench_configs)
print(f'svs tuned mean improvement:   {improvement.mean():.5f}')
# Out:
# On search datasets:
# svs default mean improvement: -0.00389
# svs tuned mean improvement:   -0.00458
#
# On bench datasets:
# svs default mean improvement: -0.00281
# svs tuned mean improvement:   -0.00274

# %% [markdown]
# # SMS parameter search

# %%
def objective(trial):
    rho = trial.suggest_categorical('rho', [-1.0, -0.5, 0.0, 0.5, 1.0])
    tau = trial.suggest_categorical('tau', [0.5, 1.0, 1.5, 2.0])
    lambda_intercept = trial.suggest_float('lambda_intercept', 1e-2, 1e2, log=True)
    lambda_diagonal = trial.suggest_float('lambda_diagonal', 1e-2, 1e2, log=True)
    lambda_off_diagonal = trial.suggest_float('lambda_off_diagonal', 1e-2, 1e2, log=True)

    sms = get_calibrator(
        'sms',
        sms_rho = rho,
        sms_tau = tau,
        sms_lambda_intercet = lambda_intercept,
        sms_lambda_diagonal = lambda_diagonal,
        sms_lambda_off_diagonal = lambda_off_diagonal
    )
    improvement = benchmark_multiclass_calibrator(sms, search_configs)

    return improvement.mean()

study = optuna.create_study()
study.optimize(objective, n_trials=50)
# Out:
# [I 2026-01-08 17:24:18,017] A new study created in memory with name: no-name-d36928fd-ae0e-4a64-9431-cc1dda8ae8cd
# [I 2026-01-08 17:27:53,434] Trial 0 finished with value: 0.003714804208044077 and parameters: {'rho': 0.0, 'tau': 2.0, 'lambda_intercept': 94.59398613565904, 'lambda_diagonal': 0.02036092790367531, 'lambda_off_diagonal': 0.011336096665675045}. Best is trial 0 with value: 0.003714804208044077.
# [I 2026-01-08 17:31:02,997] Trial 1 finished with value: -0.0007599393538375657 and parameters: {'rho': -0.5, 'tau': 1.5, 'lambda_intercept': 0.516602266345914, 'lambda_diagonal': 1.3181706956630839, 'lambda_off_diagonal': 37.13741863683784}. Best is trial 1 with value: -0.0007599393538375657.
# [I 2026-01-08 17:34:25,744] Trial 2 finished with value: 0.0020947678097399144 and parameters: {'rho': -0.5, 'tau': 1.5, 'lambda_intercept': 0.19482809298484272, 'lambda_diagonal': 0.01113256441691698, 'lambda_off_diagonal': 1.1679975694303477}. Best is trial 1 with value: -0.0007599393538375657.
# [I 2026-01-08 17:35:52,802] Trial 3 finished with value: -0.005375629154032192 and parameters: {'rho': 0.0, 'tau': 1.0, 'lambda_intercept': 2.6220848729713118, 'lambda_diagonal': 48.89097085884576, 'lambda_off_diagonal': 5.858536402129553}. Best is trial 3 with value: -0.005375629154032192.
# [I 2026-01-08 17:36:41,657] Trial 4 finished with value: -0.004756843307737574 and parameters: {'rho': 1.0, 'tau': 1.0, 'lambda_intercept': 10.621752176711535, 'lambda_diagonal': 0.05339540957766932, 'lambda_off_diagonal': 19.16908901738439}. Best is trial 3 with value: -0.005375629154032192.
# [I 2026-01-08 17:38:19,121] Trial 5 finished with value: -0.002999737932835858 and parameters: {'rho': -1.0, 'tau': 0.5, 'lambda_intercept': 44.88286129933225, 'lambda_diagonal': 57.37713034301418, 'lambda_off_diagonal': 8.195313469430111}. Best is trial 3 with value: -0.005375629154032192.
# [I 2026-01-08 17:38:40,566] Trial 6 finished with value: -0.0031414517295332233 and parameters: {'rho': 1.0, 'tau': 0.5, 'lambda_intercept': 2.3046987318368743, 'lambda_diagonal': 1.037453950289009, 'lambda_off_diagonal': 26.269058284443044}. Best is trial 3 with value: -0.005375629154032192.
# [I 2026-01-08 17:39:01,864] Trial 7 finished with value: -0.0037970443096353736 and parameters: {'rho': 1.0, 'tau': 0.5, 'lambda_intercept': 0.29748168731093255, 'lambda_diagonal': 9.46877994261085, 'lambda_off_diagonal': 0.43394766533616935}. Best is trial 3 with value: -0.005375629154032192.
# [I 2026-01-08 17:41:28,741] Trial 8 finished with value: -0.0024932130894641303 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 0.2535306009792351, 'lambda_diagonal': 0.042358795903679074, 'lambda_off_diagonal': 0.2883947477716785}. Best is trial 3 with value: -0.005375629154032192.
# [I 2026-01-08 17:42:46,439] Trial 9 finished with value: -0.005671260481824007 and parameters: {'rho': 1.0, 'tau': 1.5, 'lambda_intercept': 5.520895985194611, 'lambda_diagonal': 10.747119896072034, 'lambda_off_diagonal': 90.55661063783283}. Best is trial 9 with value: -0.005671260481824007.
# [I 2026-01-08 17:46:22,843] Trial 10 finished with value: 0.0032665144534915124 and parameters: {'rho': -1.0, 'tau': 2.0, 'lambda_intercept': 0.010534587718972557, 'lambda_diagonal': 10.432340861468314, 'lambda_off_diagonal': 0.04921424052685954}. Best is trial 9 with value: -0.005671260481824007.
# [I 2026-01-08 17:47:57,989] Trial 11 finished with value: -0.004803172368209041 and parameters: {'rho': 0.0, 'tau': 1.0, 'lambda_intercept': 3.8068245686808773, 'lambda_diagonal': 95.91841918239118, 'lambda_off_diagonal': 2.140006184943987}. Best is trial 9 with value: -0.005671260481824007.
# [I 2026-01-08 17:49:08,060] Trial 12 finished with value: -0.005411330422056598 and parameters: {'rho': 0.0, 'tau': 1.0, 'lambda_intercept': 12.344402206024492, 'lambda_diagonal': 13.235630311741641, 'lambda_off_diagonal': 94.22873359475724}. Best is trial 9 with value: -0.005671260481824007.
# [I 2026-01-08 17:50:50,197] Trial 13 finished with value: -0.006196653890726433 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 18.401153669674514, 'lambda_diagonal': 6.651981018757444, 'lambda_off_diagonal': 98.71066730748947}. Best is trial 13 with value: -0.006196653890726433.
# [I 2026-01-08 17:52:34,208] Trial 14 finished with value: -0.0062016790427755755 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 17.417835602429438, 'lambda_diagonal': 2.2897149206852716, 'lambda_off_diagonal': 98.83898433239035}. Best is trial 14 with value: -0.0062016790427755755.
# [I 2026-01-08 17:54:43,087] Trial 15 finished with value: -0.005390154536133032 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 25.840181513421207, 'lambda_diagonal': 0.2547545018882946, 'lambda_off_diagonal': 5.316417344922565}. Best is trial 14 with value: -0.0062016790427755755.
# [I 2026-01-08 17:56:38,104] Trial 16 finished with value: -0.006144658441293054 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 0.07057725691615009, 'lambda_diagonal': 2.8207295753606476, 'lambda_off_diagonal': 33.495047675852014}. Best is trial 14 with value: -0.0062016790427755755.
# [I 2026-01-08 17:58:41,675] Trial 17 finished with value: -0.005856297177889211 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 89.685891669183, 'lambda_diagonal': 0.2046737627135562, 'lambda_off_diagonal': 13.667059593286114}. Best is trial 14 with value: -0.0062016790427755755.
# [I 2026-01-08 18:00:28,059] Trial 18 finished with value: -0.006204394815636763 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 18.262626449378654, 'lambda_diagonal': 4.29249690602709, 'lambda_off_diagonal': 89.47192042183246}. Best is trial 18 with value: -0.006204394815636763.
# [I 2026-01-08 18:03:37,073] Trial 19 finished with value: -0.0008013189721120315 and parameters: {'rho': 0.5, 'tau': 2.0, 'lambda_intercept': 1.1550155453352933, 'lambda_diagonal': 0.3485617479558541, 'lambda_off_diagonal': 2.294104517147933}. Best is trial 18 with value: -0.006204394815636763.
# [I 2026-01-08 18:05:56,431] Trial 20 finished with value: -0.0028855827213839238 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 38.6804134760371, 'lambda_diagonal': 2.9738645083192186, 'lambda_off_diagonal': 0.28137823376308924}. Best is trial 18 with value: -0.006204394815636763.
# [I 2026-01-08 18:07:41,760] Trial 21 finished with value: -0.006206407953045571 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 11.360047225236512, 'lambda_diagonal': 4.252367654596762, 'lambda_off_diagonal': 95.73829186984051}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 18:09:33,039] Trial 22 finished with value: -0.006188218145217442 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 7.2823112634472835, 'lambda_diagonal': 3.3317843636707667, 'lambda_off_diagonal': 46.64521913921319}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 18:11:13,220] Trial 23 finished with value: -0.0061458505271687535 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 1.4184681189823565, 'lambda_diagonal': 28.287085679007813, 'lambda_off_diagonal': 53.16866345805375}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 18:13:13,795] Trial 24 finished with value: -0.005933535634807886 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 21.039175182901193, 'lambda_diagonal': 0.5440602007913783, 'lambda_off_diagonal': 16.01826099275633}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 18:16:41,495] Trial 25 finished with value: 0.0026075561541836012 and parameters: {'rho': -1.0, 'tau': 1.5, 'lambda_intercept': 42.06133400821317, 'lambda_diagonal': 2.151829843122397, 'lambda_off_diagonal': 10.465675099131857}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 18:19:44,689] Trial 26 finished with value: -0.001189091286821837 and parameters: {'rho': -0.5, 'tau': 1.5, 'lambda_intercept': 7.114821091194372, 'lambda_diagonal': 5.179508342155265, 'lambda_off_diagonal': 46.91449015759799}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 18:23:03,003] Trial 27 finished with value: 0.0016759319253924984 and parameters: {'rho': 0.5, 'tau': 2.0, 'lambda_intercept': 12.481733699237068, 'lambda_diagonal': 23.193193659290436, 'lambda_off_diagonal': 0.08633266709920831}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 18:23:29,605] Trial 28 finished with value: -0.0034027729430690674 and parameters: {'rho': 0.5, 'tau': 0.5, 'lambda_intercept': 3.4033230026503087, 'lambda_diagonal': 0.6390687078544922, 'lambda_off_diagonal': 66.4097818408978}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 18:26:52,924] Trial 29 finished with value: 0.0028773742567099123 and parameters: {'rho': 0.5, 'tau': 2.0, 'lambda_intercept': 83.55258499291283, 'lambda_diagonal': 1.7033718528119721, 'lambda_off_diagonal': 0.022176228626027132}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 18:29:00,014] Trial 30 finished with value: -0.005077114570748432 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 43.61999567462881, 'lambda_diagonal': 4.9723874020716385, 'lambda_off_diagonal': 2.926189878957726}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 18:30:47,135] Trial 31 finished with value: -0.0062002272372857934 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 19.304810318499268, 'lambda_diagonal': 5.336758800007172, 'lambda_off_diagonal': 95.01303894592067}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 18:32:37,564] Trial 32 finished with value: -0.006082606087611808 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 22.678452354303488, 'lambda_diagonal': 19.619061492463047, 'lambda_off_diagonal': 24.68151064618952}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 18:35:47,575] Trial 33 finished with value: -0.000608234416748568 and parameters: {'rho': -0.5, 'tau': 1.5, 'lambda_intercept': 10.667799582845667, 'lambda_diagonal': 0.92725531091081, 'lambda_off_diagonal': 33.47873205249406}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 18:37:37,717] Trial 34 finished with value: -0.006193923047954509 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 69.51571900183849, 'lambda_diagonal': 1.4609027616477526, 'lambda_off_diagonal': 55.34767255281873}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 18:40:39,723] Trial 35 finished with value: -0.002015542759336976 and parameters: {'rho': -0.5, 'tau': 1.5, 'lambda_intercept': 5.172398580151034, 'lambda_diagonal': 4.603518765395602, 'lambda_off_diagonal': 99.98817777600634}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 18:41:56,838] Trial 36 finished with value: -0.005871911969974859 and parameters: {'rho': 0.0, 'tau': 1.0, 'lambda_intercept': 0.6779524164720138, 'lambda_diagonal': 7.264402989127068, 'lambda_off_diagonal': 19.68597703320874}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 18:45:26,031] Trial 37 finished with value: 0.002875251606530957 and parameters: {'rho': -1.0, 'tau': 1.5, 'lambda_intercept': 2.192008737569113, 'lambda_diagonal': 1.9097025947540673, 'lambda_off_diagonal': 6.571104928202063}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 18:45:59,393] Trial 38 finished with value: -0.003657133376084435 and parameters: {'rho': 0.5, 'tau': 0.5, 'lambda_intercept': 29.148370219425072, 'lambda_diagonal': 0.11480536868678297, 'lambda_off_diagonal': 30.56179825203232}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 18:47:11,924] Trial 39 finished with value: -0.005654861915570185 and parameters: {'rho': 1.0, 'tau': 1.5, 'lambda_intercept': 17.47174793767155, 'lambda_diagonal': 37.48626306005993, 'lambda_off_diagonal': 61.79630318977491}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 18:49:27,933] Trial 40 finished with value: -0.0035719690194135957 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 60.629142602478275, 'lambda_diagonal': 0.8042690012511464, 'lambda_off_diagonal': 0.6351119183394456}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 18:51:11,224] Trial 41 finished with value: -0.006200931751872166 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 15.537793046635121, 'lambda_diagonal': 6.211143505389125, 'lambda_off_diagonal': 95.60931511391408}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 18:52:52,541] Trial 42 finished with value: -0.006181022176726497 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 9.744756777734741, 'lambda_diagonal': 16.386297087907263, 'lambda_off_diagonal': 66.00400880917626}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 18:54:43,543] Trial 43 finished with value: -0.006166886688558031 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 14.719676459786882, 'lambda_diagonal': 3.29104540193103, 'lambda_off_diagonal': 37.33925934877209}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 18:55:38,707] Trial 44 finished with value: -0.005160466849261399 and parameters: {'rho': 0.5, 'tau': 1.0, 'lambda_intercept': 0.10838906159060954, 'lambda_diagonal': 7.496126438952665, 'lambda_off_diagonal': 22.128836110776707}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 18:56:11,883] Trial 45 finished with value: -0.0038617149654776926 and parameters: {'rho': 0.0, 'tau': 0.5, 'lambda_intercept': 7.621327024273479, 'lambda_diagonal': 1.1806669080121488, 'lambda_off_diagonal': 68.70794618385007}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 18:57:24,502] Trial 46 finished with value: -0.00564271399303624 and parameters: {'rho': 1.0, 'tau': 1.5, 'lambda_intercept': 31.032615430623835, 'lambda_diagonal': 10.218127696644054, 'lambda_off_diagonal': 99.85169621279782}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 19:00:57,586] Trial 47 finished with value: 0.002351796893682679 and parameters: {'rho': -1.0, 'tau': 1.5, 'lambda_intercept': 4.074520131348777, 'lambda_diagonal': 0.015017840509242056, 'lambda_off_diagonal': 11.82176968087913}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 19:03:48,413] Trial 48 finished with value: -0.00408396103395342 and parameters: {'rho': 0.5, 'tau': 2.0, 'lambda_intercept': 15.129520165499944, 'lambda_diagonal': 4.867801941328707, 'lambda_off_diagonal': 40.52775811994721}. Best is trial 21 with value: -0.006206407953045571.
# [I 2026-01-08 19:05:34,957] Trial 49 finished with value: -0.00619224296628105 and parameters: {'rho': 0.5, 'tau': 1.5, 'lambda_intercept': 50.028815818143464, 'lambda_diagonal': 13.188048431098425, 'lambda_off_diagonal': 73.56089292461968}. Best is trial 21 with value: -0.006206407953045571.

# %%
sms_default = get_calibrator('sms')

sms_tuned = get_calibrator(
    'sms',
    sms_rho = study.best_params['rho'],
    sms_tau = study.best_params['tau'],
    sms_lambda_intercet = study.best_params['lambda_intercept'],
    sms_lambda_diagonal = study.best_params['lambda_diagonal'],
    sms_lambda_off_diagonal = study.best_params['lambda_off_diagonal']
)

# %%
print('On search datasets:')
improvement = benchmark_multiclass_calibrator(sms_default, search_configs)
print(f'sms default mean improvement: {improvement.mean():.5f}')
improvement = benchmark_multiclass_calibrator(sms_tuned, search_configs)
print(f'sms tuned mean improvement:   {improvement.mean():.5f}\n')

print('On bench datasets:')
improvement = benchmark_multiclass_calibrator(sms_default, bench_configs)
print(f'sms default mean improvement: {improvement.mean():.5f}')
improvement = benchmark_multiclass_calibrator(sms_tuned, bench_configs)
print(f'sms tuned mean improvement:   {improvement.mean():.5f}')
# Out:
# On search datasets:
# sms default mean improvement: -0.00566
# sms tuned mean improvement:   -0.00621
#
# On bench datasets:
# sms default mean improvement: -0.00360
# sms tuned mean improvement:   -0.00355
